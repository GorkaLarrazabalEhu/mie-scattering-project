# %%
import numpy as np
import miepython
import matplotlib.pyplot as plt

# %%
#link = "https://refractiveindex.info/tmp/database/data-nk/main/TiO2/Devore-o.txt"
#tiData = np.genfromtxt(link, delimiter = '\t')

#waveLength = tiData[:,0]
#refractiveIndex = tiData[:,1]

waveLength = np.linspace(5,15,1000)*10**(-7)
refractiveIndex = (5.913 + 0.2441 / (waveLength**2 - 0.0803))**.5 #solo tiene parte real

# %%
plt.plot(waveLength*10**6, refractiveIndex, "red")
